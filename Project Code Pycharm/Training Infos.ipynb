# %%
import pandas as pd

pd.read_csv('model_infos.csv')
# Out:
#                                 Best Hyperparameters  \
# 0                        {'feature_selector__k': 43}
# 1  {'feature_selector__k': 40, 'estimator__min_sa...
# 2  {'feature_selector__k': 25, 'estimator__weight...
#
#    Default Model CV Mean Score  \
# 0                     0.779959
# 1                     0.875775
# 2                     0.810456
#
#                              Default Model CV Scores  \
# 0  [0.77993321 0.78211579 0.76678166 0.79736434 0...
# 1  [0.89159808 0.85782236 0.87665484 0.86995319 0...
# 2  [0.78934931 0.81210484 0.78348281 0.84421464 0...
#
#                                 Default Model Object  \
# 0  Pipeline(steps=[('feature_selector',\n        ...
# 1  Pipeline(steps=[('feature_selector',\n        ...
# 2  Pipeline(steps=[('feature_selector',\n        ...
#
#    Default Model Test Score  Default Model Training Score  \
# 0                  0.789079                      0.783347
# 1                  0.879466                      0.970033
# ...
